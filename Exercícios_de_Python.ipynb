# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaPSants/LeticiaSanto/blob/main/Exerc%C3%ADcios_de_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade=int(input("Digite sua idade:"))
if idade>=18:
  print("Você é maior de idade!")
else:
  print("Você é menor de idade!")
# Out:
# Digite sua idade:20
# Você é maior de idade!

# %%
numero=int(input("Digite um número:"))
if numero>0:
  print("Esse numero é positivo")
else:
  print("Esse numero é negativo!")
# Out:
# Digite um número:2
# Esse numero é positivo

# %%
nota=float(input("Digite sua nota:"))
if nota>=7:
  print("Aprovado!")
elif nota>=5:
  print("Recuperação!")
else:
  print("Reprovado")
# Out:
# Digite um número:5
# Recuperação!

# %%
numero=int(input("Digite um número:"))
if numero %2==0:
  print("Seu número é par!")
else:
  print("Seu número é ímpar!")
# Out:
# Digite um número:7
# Seu número é ímpar!

# %%
senha=int(input("Digite sua senha!:"))
if senha==1234:
  print("Sua senha está correta!")
else:
  print("Sua senha está incorreta!")
# Out:
# Digite um número:1234
# Sua senha está correta!

# %%
numero1=int(input("Digite um número:"))
numero2=int(input("Digite um número:"))
if numero1>numero2:
  print("O primeiro número é maior que o segundo")
elif numero1==numero2:
  print("Os números são iguais")
else:
  print("O segundo numero é maior que o primeiro")
# Out:
# Digite um número:100
# Digite um número:99
# O primeiro número é maior que o segundo

# %%
idade=int(input("Digite sua idade:"))
if idade>=16:
  print("Você pode votar!")
else:
  print("Você não pode votar!")
# Out:
# Digite sua idade:18
# Você pode votar!

# %%
nota1=float(input("Digite sua primeira nota:"))
nota2=float(input("Digite sua segunda nota:"))
nota3=float(input("Digite sua terceira nota:"))

soma=nota1+nota2+nota3
if soma/3>=7:
  print("Parabéns, você foi aprovado!")
elif soma/3>=5:
  print("Que pena, você ficou de recuperação")
else:
  print("Você está Reprovado, se esforce mais!")
# Out:
# Digite sua primeira nota:1
# Digite sua segunda nota:3
# Digite sua terceira nota:2
# Você está Reprovado, se esforce mais!

# %%
valorProduto=float(input("Digite o valor do Produto:"))
if valorProduto>500:
  print("O produto está caro!")
elif valorProduto<100:
  print("O produto está barato!")
else:
  print("O produto está com o preço normal")
# Out:
# Digite o valor do Produto:200
# O produto está com o preço normal

# %%
idade=int(input("Informe seu ano de nascimento:"))
if 2025 - idade >=18:
  print("Você é maior de idade!")
else:
  print("Você é menor de idade!")
# Out:
# Informe seu ano de nascimento:1993
# Você é maior de idade!

# %%
nome=input("Qual é seu nome? ")
print(f"Seja Bem-Vinda, {nome}")
# Out:
# Qual é seu nome? Letícia
# Seja Bem-Vinda, Letícia
