# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaPSants/LeticiaSanto/blob/main/Repeti%C3%A7%C3%B5es_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite um número: "))

for i in range(1, n + 1):
    if i % 2 != 0:
        print(i)
# Out:
# Digite um número: 6
# 1
# 3
# 5

# %%
n = int(input("Digite um número: "))
for i in range(1, 11):
   print(i * 6)
# Out:
# Digite um número: 3
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60

# %%
n = 2
x = 1
while x <= 10:
  resultado = n*x
  print(n, "x", x, "=", resultado)
  x = x + 1
# Out:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
